# %%
import numpy as np 
students = np.array([[67,94,65], [88,82,78], [75,90,85]])   
students
# Out:
# array([[67, 94, 65],
#        [88, 82, 78],
#        [75, 90, 85]])

# %%
import pandas as pd
df = pd.DataFrame(data=students,index=['stud1','stud2','stud3'], columns=['Math', 'Physics', 'Chemistry'])
df
# Out:
#        Math  Physics  Chemistry
# stud1    67       94         65
# stud2    88       82         78
# stud3    75       90         85

# %%
data = np.random.randint(50,high=101,size=(50,5))
students = pd.DataFrame(data,columns=['Math', 'Physics', 'Chemistry', 'Biology', 'History'])
students
# Out:
#     Math  Physics  Chemistry  Biology  History
# 0     76       96         94       63       83
# 1     90       90         51       92       98
# 2     65       75         83       59       81
# 3     78       69         73       58       53
# 4     52       69         99       63       85
# 5     96       60         87       57       86
# 6     91       98         66       83       73
# 7     80       51         53       71      100
# 8     96       60         78       76       86
# 9     72       79         99       94       96
# 10    87       98         98       77       60
# 11    56       82         79       99       71
# 12    93       81         63       87       96
# 13    85       69         67       79       67
# 14    95       74         57       69       98
# 15    81       64         59       81       85
# 16    60       92         90       85       91
# 17    57       55         61       54       80
# 18    77       60         82       69       72
# ...

# %%
student_nums = 5
np.random.randint(50,high=101,size=(student_nums,5))
# Out:
# array([[ 91, 100,  88,  93,  79],
#        [ 86,  67,  98,  75,  80],
#        [ 57,  77,  91,  69,  78],
#        [ 60,  72,  65,  91,  54],
#        [ 52,  60,  53,  71,  61]])

# %%
import random
def get_names(nums:int=10)->list[str]:
    with open('names.txt',encoding='utf-8') as file:
        content = file.read()
        names = content.split("\n")
        randam_names = random.sample(names,nums)
        
    return randam_names

get_names(5)
# Out:
# ['簡國瑋', '邱亭君', '林瑞喬', '林世城', '鞠冠宇']

# %%
student_nums = 5
data = np.random.randint(50,high=101,size=(student_nums, 5))
students = pd.DataFrame(data,
             columns=['國文','英文','數學','地理','探討'],
             index=get_names(student_nums))
students
students.to_excel('students.xlsx')

# %%
students.to_csv('student.csv')
print("csv存檔成功")
# Out:
# csv存檔成功

# %%
import pandas as pd
df = pd.read_csv('student.csv',index_col=0)
df
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  74  94  85
# 李政成  77  97  84  63  75
# 陳彥治  57  80  62  62  96
# 陳姵彬  67  51  76  98  98
# 林瑞喬  84  51  58  58  69

# %%
df = pd.read_excel('students.xlsx',index_col=0)
df
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  74  94  85
# 李政成  77  97  84  63  75
# 陳彥治  57  80  62  62  96
# 陳姵彬  67  51  76  98  98
# 林瑞喬  84  51  58  58  69

# %%
df["國文"]
# Out:
# 黃必琪    95
# 李政成    77
# 陳彥治    57
# 陳姵彬    67
# 林瑞喬    84
# Name: 國文, dtype: int64

# %%
df[["國文","數學"]]
# Out:
#      國文  數學
# 黃必琪  95  74
# 李政成  77  84
# 陳彥治  57  62
# 陳姵彬  67  76
# 林瑞喬  84  58

# %%
df.loc[["黃必琪","陳姵彬"]]
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  74  94  85
# 陳姵彬  67  51  76  98  98

# %%
df.iloc[0]
# Out:
# 國文    95
# 英文    99
# 數學    74
# 地理    94
# 探討    85
# Name: 黃必琪, dtype: int64

# %%
df.iloc[0:3]
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  74  94  85
# 李政成  77  97  84  63  75
# 陳彥治  57  80  62  62  96

# %%
df.loc["黃必琪","數學"]='85'
df.head()
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  85  94  85
# 李政成  77  97  84  63  75
# 陳彥治  57  80  62  62  96
# 陳姵彬  67  51  76  98  98
# 林瑞喬  84  51  58  58  69

# %%
df[:3]
# Out:
#      國文  英文  數學  地理  探討
# 黃必琪  95  99  85  94  85
# 李政成  77  97  84  63  75
# 陳彥治  57  80  62  62  96

# %%
df[-1:]
# Out:
#      國文  英文  數學  地理  探討
# 林瑞喬  84  51  58  58  69

# %%
df
stu_sum = df.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 df
# ----> 2 stu_sum = df.sum(axis=1)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df.sum(axis=1)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
# ...
